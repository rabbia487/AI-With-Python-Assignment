# %% [markdown]
# **PART 1**

# %% [markdown]
# **Qno1:would you say that deep was intelligen**?
#
# answer
# Deep blue was intelligent in a limited way .it could calculate millions of chess moves very quickly ,but it could not think,ubderstand or reason like human therfore ,it was a Narrow AI.

# %% [markdown]
# **Qno2:what contributed to Deep blues success and who should get credit for it**
#
# ANSWER:
# Deep blue succeeded because of its powerful computing ability and the work of engineers who built.both the machine and its human creators derve credit but the greatest credit goes to the who designed and programmed it.

# %% [markdown]
# **part 2**

# %% [markdown]
# **Qno1 what implications do you think such digital assistants will have for people?**
# answer:
# Digital assistance can make everyday tasks easier and save time.people can use them to book appointments,make reservation,get information ,set reminders and perform routine tasks without having to do everything themselves.
# Qno2 what opportunities might it open for businesses?
# answer:
# Google duples can help businesses manage customer requests more effciently .it can automate tasks such as book appointments,answering coomon question, and handling reservation.This can reduce workload for employee improve customer service and save time

# %% [markdown]
# **Qno2 what oppoertunities might it open for bussinesses?**
#
# answer:
# Google duplex can help businesses manage customer requests more effciently.it can automate tasks such as booking appoinments ,answering common questios,and handling  reservations.this can reduce workload for employee,improve customer service and save time.

# %% [markdown]
# **Qno3 is google duplex narrow,general or super AI?**
#
# answer:
#
# Google duplex is  an example of Narrow AI

# %% [markdown]
# **Qno4 what impressed you most in this demo?**
#
# what impressed me most was how naturally Google duplex spoke during the phone conversation. the AI was able to understand the discussion,respond appropriately,and even use natural pauses and expression that made it sound very similar to a real human

# %% [markdown]
# **pART 3**

# %% [markdown]
# **Qno1 what does the author say about importance of the  Turung Test?**
# anser:
# Turing believed that the Turning test is a way to determine whether a machine can imitate intelligence in conversation.

# %% [markdown]
# **Qno2 how is the Turning test conducted?**
#
# A human judge chats with both human and a computer through text.if the judge cannot reliably tell wgich is the machine the computer is said to have passed the test.

# %% [markdown]
# **Qno3 what did Turning predict would happen by 2000 ?did it happen in your opinion?**
#
#
# Turning predicted that by the year 2000, computers would be able to fool humans in conversation for a short time.in my opinion ,this prediction was largely correct because modern chatbots can often have very human like conversations.

# %% [markdown]
# **Qno4 who was Eugene Goostman?**
#
#
# Eugene Goostman was a chatbot designed to act like a 13-year-old boy from ukraine.it became famous for reportdly convincing some judges that it was human during turing test compititions.
